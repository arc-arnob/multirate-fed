# %%
import os
import pandas as pd
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
import dateutil.parser
import matplotlib.pyplot as plt
# --------------------------- #
#        Data Preprocessing   #
# --------------------------- #

def load_and_preprocess_site_data(site_path, window_size=32, horizon=16, min_date=None, max_date=None):
    """
    Loads and preprocesses time series data for a given site.

    Args:
    - site_path (str): Path to the site CSV file.
    - window_size (int): Number of past time steps for input.
    - horizon (int): Number of future steps to predict.

    Returns:
    - train_loader, val_loader, test_loader: DataLoaders for training, validation, and testing.
    """
    df = pd.read_csv(site_path)
    
    # Convert date column to datetime if it exists
    if 'date' in df.columns:
        df['date'] = pd.to_datetime(df['date'])

        # Filter data between min_date and max_date
        if min_date:
            min_date = dateutil.parser.parse(min_date) if isinstance(min_date, str) else min_date
            df = df[df['date'] >= min_date]

        if max_date:
            max_date = dateutil.parser.parse(max_date) if isinstance(max_date, str) else max_date
            df = df[df['date'] <= max_date]

        # Drop the date column after filtering
        df.drop(columns=['date'], inplace=True)
        
    
    # Perform an 80-20 split based on time order
    train_size = int(0.8 * len(df))
    train_df = df.iloc[:train_size]  # 80% for training & validation
    test_df = df.iloc[train_size:]   # 20% for final testing (future unseen data)

    # Split train_df further into Train (80%) and Validation (20%)
    val_size = int(0.2 * len(train_df))  # 16% of full dataset
    train_df, val_df = train_df.iloc[:-val_size], train_df.iloc[-val_size:]

    print(f"Train size: {len(train_df)} | Validation size: {len(val_df)} | Test size: {len(test_df)}")

    # Standardize each separately to prevent data leakage
    train_mean, train_std = train_df.mean(), train_df.std()
    
    train_df = (train_df - train_mean) / (train_std + 1e-8)
    val_df = (val_df - train_mean) / (train_std + 1e-8)  # Normalize validation using train stats
    test_df = (test_df - train_mean) / (train_std + 1e-8)  # Normalize test using train stats

    # Convert DataFrame to NumPy arrays for LSTM
    X_train, y_train = df_to_X_y(train_df,window_size, horizon)
    X_val, y_val = df_to_X_y(val_df, window_size, horizon)
    X_test, y_test = df_to_X_y(test_df, window_size, horizon)

    # Convert to PyTorch tensors
    train_data = TensorDataset(torch.from_numpy(X_train).float(), torch.from_numpy(y_train).float())
    val_data = TensorDataset(torch.from_numpy(X_val).float(), torch.from_numpy(y_val).float())
    test_data = TensorDataset(torch.from_numpy(X_test).float(), torch.from_numpy(y_test).float())

    # Create DataLoaders
    batch_size = 32
    train_loader = DataLoader(train_data, shuffle=True, batch_size=batch_size, drop_last=True)
    val_loader = DataLoader(val_data, shuffle=False, batch_size=batch_size, drop_last=True)
    test_loader = DataLoader(test_data, shuffle=False, batch_size=batch_size, drop_last=True)

    return train_loader, val_loader, test_loader


def df_to_X_y(df, window_size=32, horizon=16):
    """
    Converts a DataFrame into supervised learning format for LSTM.

    Args:
    - df (pd.DataFrame): DataFrame containing time series.
    - window_size (int): Past window size.
    - horizon (int): Number of future steps.

    Returns:
    - X (np.array): Features.
    - y (np.array): Targets.
    """
    if "OT" not in df.columns:
        raise ValueError("The target column 'OT' is missing from the DataFrame.")

    df_as_np = df.to_numpy()
    target_col_idx = df.columns.get_loc("OT")  # Get the index of 'OT' column

    X, y = [], []

    for i in range(len(df_as_np) - window_size - horizon + 1):
        X.append(df_as_np[i:i + window_size])  # Past 'window_size' rows as features
        y.append(df_as_np[i + window_size:i + window_size + horizon, target_col_idx])  # Next 'horizon' steps for target

    return np.array(X), np.array(y)



# --------------------------- #
#          LSTM Model         #
# --------------------------- #

class LSTMModel(nn.Module):
    def __init__(self, num_features, time_window, output_window, num_labels, num_layers=2, hidden_size=16, dropout=0.2):
        super(LSTMModel, self).__init__()
        self.output_window = output_window
        self.num_labels = num_labels

        self.lstm = nn.LSTM(num_features,
                            hidden_size,
                            num_layers=num_layers,
                            batch_first=True,
                            dropout=dropout)
        
        self.fc = nn.Linear(hidden_size, num_labels * output_window)

    def forward(self, x):
        B, T, D = x.shape  
        x_, _ = self.lstm(x)
        last_hidden = x_[:, -1, :]  # Take last time step's hidden state
        x_ = self.fc(last_hidden)
        x_ = x_.reshape(B, self.output_window, self.num_labels)
        return x_


# --------------------------- #
#      Training Function      #
# --------------------------- #

def train_model(model, train_loader, val_loader, num_epochs=30, lr=1e-3, wd=1e-5):
    """
    Trains an LSTM model with validation.

    Args:
    - model (nn.Module): The LSTM model.
    - train_loader (DataLoader): DataLoader for training.
    - val_loader (DataLoader): DataLoader for validation.
    - num_epochs (int): Number of training epochs.
    - lr (float): Learning rate.

    Returns:
    - None
    """
    criterion = nn.MSELoss()
    optimizer = optim.Adam(model.parameters(), lr=lr,weight_decay=wd)
    device = "cuda"

    model.to(device)
    
    train_losses = []
    val_losses = []

    for epoch in range(num_epochs):
        # print(f"\nEPOCH {epoch+1}")
        
        # -------------------- Training -------------------- #
        model.train()
        running_train_loss = 0.0
        
        for batch_x, batch_y in train_loader:
            batch_x, batch_y = batch_x.to(device), batch_y.to(device)

            output = model(batch_x)
            loss = criterion(output, batch_y.unsqueeze(-1))  # Ensure correct shape
            running_train_loss += loss.item()

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

        avg_train_loss = running_train_loss / len(train_loader)
        avg_train_loss = running_train_loss / len(train_loader)
        train_losses.append(avg_train_loss)

        # -------------------- Validation -------------------- #
        model.eval()
        running_val_loss = 0.0

        with torch.no_grad():  # Disable gradient calculations
            for batch_x, batch_y in val_loader:
                batch_x, batch_y = batch_x.to(device), batch_y.to(device)

                output = model(batch_x)
                loss = criterion(output, batch_y.unsqueeze(-1))  # Ensure correct shape
                running_val_loss += loss.item()

        avg_val_loss = running_val_loss / len(val_loader)
        avg_val_loss = running_val_loss / len(val_loader)
        val_losses.append(avg_val_loss)


        # Print losses for the epoch
        print(f"Train Loss: {avg_train_loss:.4f} | Validation Loss: {avg_val_loss:.4f}")

    print("Training complete!")
     # -------------------- Plot Loss Curves -------------------- #

    # plt.figure(figsize=(8, 5))
    # plt.plot(range(1, num_epochs + 1), train_losses, label="Training Loss", marker='o')
    # plt.plot(range(1, num_epochs + 1), val_losses, label="Validation Loss", marker='s')
    
    # plt.xlabel("Epoch")
    # plt.ylabel("Loss")
    # plt.title("Training and Validation Loss Curves")
    # plt.legend()
    # plt.grid(True)
    # plt.show()

    return train_losses, val_losses



# --------------------------- #
#      Evaluation Function    #
# --------------------------- #

def evaluate_model(model, test_loader):
    """
    Evaluates the LSTM model on test data.

    Args:
    - model (nn.Module): Trained LSTM model.
    - test_loader (DataLoader): DataLoader for testing.

    Returns:
    - mean_mae (float): Mean Absolute Error.
    """
    model.eval()
    criterion = nn.L1Loss()
    mae_list = []

    with torch.no_grad():
        for batch_x, batch_y in test_loader:
            batch_x, batch_y = batch_x.to("cuda"), batch_y.to("cuda")
            predictions = model(batch_x)
            mae = criterion(predictions, batch_y.unsqueeze(-1)).item()
            mae_list.append(mae)

    return np.mean(mae_list)

# %%
site_directory = "../processed_ds/stores_data/"
site_files = [os.path.join(site_directory, f, f"{f}.csv") for f in os.listdir(site_directory) if os.path.isdir(os.path.join(site_directory, f))]

# %%
# --------------------------- #
#    Run Experiments for All Sites #
# --------------------------- #

# Directory containing all site data
# site_directory = "../processed_ds/air_quality_cluster/"
# min_date = "2014-09-01"
# max_date = "2014-11-12 19:00"
# num_features = 11
# site_directory = "../processed_ds/solar/"
# min_date = "2006-09-01"
# max_date = "2006-09-08 4:50"
# num_features = 10
# site_directory = "../processed_ds/crypto-data/"
# min_date = "2018-04-01"
# max_date = "2018-06-15"
# num_features = 5
site_directory = "../processed_ds/stores_data/"
min_date = "2013-01-16"
max_date = "2015-07-31"
num_features = 7
site_files = [os.path.join(site_directory, f, f"{f}.csv") for f in os.listdir(site_directory) if os.path.isdir(os.path.join(site_directory, f))]

all_mae = []

for site_path in site_files:
    print(f"\nProcessing Site: {site_path}")

    # Load data Crypto target_col = 3
    train_loader, val_loader, test_loader = load_and_preprocess_site_data(site_path,min_date=min_date, max_date=max_date)

    # Define LSTM Model
    model = LSTMModel(num_features=num_features, time_window=32, output_window=16, num_labels=1, num_layers=2, hidden_size=128, dropout=0.1)

    # Train the model
    train_model(model, train_loader, val_loader ,num_epochs=30, lr=1e-3, wd=1e-3)

    # Evaluate the model
    mae = evaluate_model(model, test_loader)
    print(f"MAE for {site_path}: {mae:.4f}")
    all_mae.append(mae)

# Compute average MAE across all sites
avg_mae = np.mean(all_mae)
print(f"\nAverage MAE Across All Sites: {avg_mae:.4f}")
# Out:
# Processing Site: ../processed_ds/stores_data/store-631/store-631.csv
# Train size: 593 | Validation size: 148 | Test size: 186
# Train Loss: 0.9824 | Validation Loss: 0.7408
# Train Loss: 0.9603 | Validation Loss: 0.7109
# Train Loss: 0.8804 | Validation Loss: 0.5920
# Train Loss: 0.7531 | Validation Loss: 0.5344
# Train Loss: 0.6534 | Validation Loss: 0.4000
# Train Loss: 0.5077 | Validation Loss: 0.2973
# Train Loss: 0.4216 | Validation Loss: 0.2184
# Train Loss: 0.3476 | Validation Loss: 0.1925
# Train Loss: 0.3100 | Validation Loss: 0.1664
# Train Loss: 0.3000 | Validation Loss: 0.1682
# Train Loss: 0.2918 | Validation Loss: 0.1757
# Train Loss: 0.2939 | Validation Loss: 0.1676
# Train Loss: 0.2913 | Validation Loss: 0.1810
# Train Loss: 0.2919 | Validation Loss: 0.1691
# Train Loss: 0.2882 | Validation Loss: 0.1704
# Train Loss: 0.2859 | Validation Loss: 0.1623
# Train Loss: 0.2879 | Validation Loss: 0.1585
# Train Loss: 0.2837 | Validation Loss: 0.1851
# Train Loss: 0.2792 | Validation Loss: 0.1812
# Train Loss: 0.2791 | Validation Loss: 0.1965
# Train Loss: 0.2800 | Validation Loss: 0.1617
# Train Loss: 0.2730 | Validation Loss: 0.1664
# Train Loss: 0.2743 | Validation Loss: 0.1584
# Train Loss: 0.2698 | Validation Loss: 0.1712
# Train Loss: 0.2677 | Validation Loss: 0.1834
# Train Loss: 0.2650 | Validation Loss: 0.1649
# Train Loss: 0.2646 | Validation Loss: 0.1736
# Train Loss: 0.2603 | Validation Loss: 0.1844
# Train Loss: 0.2609 | Validation Loss: 0.1723
# Train Loss: 0.2559 | Validation Loss: 0.2046
# Training complete!
# MAE for ../processed_ds/stores_data/store-631/store-631.csv: 0.3497
#
# Processing Site: ../processed_ds/stores_data/store-602/store-602.csv
# Train size: 593 | Validation size: 148 | Test size: 186
# Train Loss: 0.9842 | Validation Loss: 0.7325
# Train Loss: 0.9602 | Validation Loss: 0.6844
# Train Loss: 0.8739 | Validation Loss: 0.5762
# Train Loss: 0.7631 | Validation Loss: 0.5143
# Train Loss: 0.6759 | Validation Loss: 0.4054
# Train Loss: 0.5183 | Validation Loss: 0.2715
# Train Loss: 0.4048 | Validation Loss: 0.1767
# Train Loss: 0.3363 | Validation Loss: 0.1467
# Train Loss: 0.3129 | Validation Loss: 0.1343
# Train Loss: 0.3035 | Validation Loss: 0.1374
# Train Loss: 0.2965 | Validation Loss: 0.1332
# Train Loss: 0.2957 | Validation Loss: 0.1366
# Train Loss: 0.2966 | Validation Loss: 0.1273
# Train Loss: 0.2957 | Validation Loss: 0.1509
# Train Loss: 0.2930 | Validation Loss: 0.1300
# Train Loss: 0.2912 | Validation Loss: 0.1214
# Train Loss: 0.2882 | Validation Loss: 0.1408
# Train Loss: 0.2862 | Validation Loss: 0.1379
# Train Loss: 0.2917 | Validation Loss: 0.1296
# Train Loss: 0.2933 | Validation Loss: 0.1334
# Train Loss: 0.2851 | Validation Loss: 0.1443
# Train Loss: 0.2828 | Validation Loss: 0.1432
# Train Loss: 0.2815 | Validation Loss: 0.1417
# Train Loss: 0.2804 | Validation Loss: 0.1375
# Train Loss: 0.2763 | Validation Loss: 0.1541
# Train Loss: 0.2789 | Validation Loss: 0.1545
# Train Loss: 0.2769 | Validation Loss: 0.1400
# Train Loss: 0.2747 | Validation Loss: 0.1421
# Train Loss: 0.2746 | Validation Loss: 0.1523
# Train Loss: 0.2718 | Validation Loss: 0.1360
# Training complete!
# MAE for ../processed_ds/stores_data/store-602/store-602.csv: 0.3593
#
# Processing Site: ../processed_ds/stores_data/store-873/store-873.csv
# Train size: 593 | Validation size: 148 | Test size: 186
# Train Loss: 0.9845 | Validation Loss: 0.7437
# Train Loss: 0.9339 | Validation Loss: 0.6428
# Train Loss: 0.7474 | Validation Loss: 0.5212
# Train Loss: 0.6228 | Validation Loss: 0.4129
# Train Loss: 0.4967 | Validation Loss: 0.2720
# Train Loss: 0.3975 | Validation Loss: 0.2098
# Train Loss: 0.3475 | Validation Loss: 0.1792
# Train Loss: 0.3166 | Validation Loss: 0.1657
# Train Loss: 0.3058 | Validation Loss: 0.1528
# Train Loss: 0.2986 | Validation Loss: 0.1576
# Train Loss: 0.2944 | Validation Loss: 0.1477
# Train Loss: 0.2923 | Validation Loss: 0.1420
# Train Loss: 0.2919 | Validation Loss: 0.1411
# Train Loss: 0.2896 | Validation Loss: 0.1392
# Train Loss: 0.2860 | Validation Loss: 0.1442
# Train Loss: 0.2845 | Validation Loss: 0.1492
# Train Loss: 0.2827 | Validation Loss: 0.1485
# Train Loss: 0.2827 | Validation Loss: 0.1406
# Train Loss: 0.2796 | Validation Loss: 0.1428
# Train Loss: 0.2798 | Validation Loss: 0.1439
# Train Loss: 0.2783 | Validation Loss: 0.1487
# Train Loss: 0.2806 | Validation Loss: 0.1394
# Train Loss: 0.2788 | Validation Loss: 0.1428
# Train Loss: 0.2745 | Validation Loss: 0.1399
# Train Loss: 0.2745 | Validation Loss: 0.1493
# Train Loss: 0.2732 | Validation Loss: 0.1301
# Train Loss: 0.2700 | Validation Loss: 0.1454
# Train Loss: 0.2660 | Validation Loss: 0.1336
# Train Loss: 0.2624 | Validation Loss: 0.1326
# Train Loss: 0.2620 | Validation Loss: 0.1259
# Training complete!
# MAE for ../processed_ds/stores_data/store-873/store-873.csv: 0.3176
#
# Processing Site: ../processed_ds/stores_data/store-734/store-734.csv
# Train size: 593 | Validation size: 148 | Test size: 186
# Train Loss: 0.9773 | Validation Loss: 0.8370
# Train Loss: 0.9440 | Validation Loss: 0.7667
# Train Loss: 0.8257 | Validation Loss: 0.6083
# Train Loss: 0.6833 | Validation Loss: 0.4982
# Train Loss: 0.5902 | Validation Loss: 0.3911
# Train Loss: 0.4621 | Validation Loss: 0.2927
# Train Loss: 0.3959 | Validation Loss: 0.2602
# Train Loss: 0.3701 | Validation Loss: 0.2410
# Train Loss: 0.3417 | Validation Loss: 0.2155
# Train Loss: 0.3304 | Validation Loss: 0.2101
# Train Loss: 0.3253 | Validation Loss: 0.2044
# Train Loss: 0.3238 | Validation Loss: 0.2081
# Train Loss: 0.3191 | Validation Loss: 0.2089
# Train Loss: 0.3161 | Validation Loss: 0.2048
# Train Loss: 0.3165 | Validation Loss: 0.2046
# Train Loss: 0.3196 | Validation Loss: 0.1966
# Train Loss: 0.3192 | Validation Loss: 0.2150
# Train Loss: 0.3124 | Validation Loss: 0.1982
# Train Loss: 0.3184 | Validation Loss: 0.2174
# Train Loss: 0.3119 | Validation Loss: 0.1971
# Train Loss: 0.3090 | Validation Loss: 0.2165
# Train Loss: 0.3082 | Validation Loss: 0.1984
# Train Loss: 0.3064 | Validation Loss: 0.2104
# Train Loss: 0.3069 | Validation Loss: 0.2000
# Train Loss: 0.3036 | Validation Loss: 0.1979
# Train Loss: 0.3077 | Validation Loss: 0.2008
# Train Loss: 0.3033 | Validation Loss: 0.2028
# Train Loss: 0.3026 | Validation Loss: 0.2111
# Train Loss: 0.3009 | Validation Loss: 0.1923
# Train Loss: 0.3015 | Validation Loss: 0.2057
# Training complete!
# MAE for ../processed_ds/stores_data/store-734/store-734.csv: 0.5458
#
# Processing Site: ../processed_ds/stores_data/store-844/store-844.csv
# Train size: 593 | Validation size: 148 | Test size: 186
# Train Loss: 0.9844 | Validation Loss: 0.8473
# Train Loss: 0.9457 | Validation Loss: 0.7675
# Train Loss: 0.7940 | Validation Loss: 0.5848
# Train Loss: 0.6527 | Validation Loss: 0.4824
# Train Loss: 0.5380 | Validation Loss: 0.3448
# Train Loss: 0.4307 | Validation Loss: 0.2793
# Train Loss: 0.3685 | Validation Loss: 0.2156
# Train Loss: 0.3339 | Validation Loss: 0.2026
# Train Loss: 0.3142 | Validation Loss: 0.1771
# Train Loss: 0.3064 | Validation Loss: 0.1977
# Train Loss: 0.3030 | Validation Loss: 0.1802
# Train Loss: 0.2967 | Validation Loss: 0.1863
# Train Loss: 0.2989 | Validation Loss: 0.1754
# Train Loss: 0.3000 | Validation Loss: 0.1826
# Train Loss: 0.2983 | Validation Loss: 0.1739
# Train Loss: 0.2956 | Validation Loss: 0.2037
# Train Loss: 0.2960 | Validation Loss: 0.1806
# Train Loss: 0.2910 | Validation Loss: 0.1718
# Train Loss: 0.2898 | Validation Loss: 0.1845
# Train Loss: 0.2873 | Validation Loss: 0.1979
# Train Loss: 0.2871 | Validation Loss: 0.1728
# Train Loss: 0.2890 | Validation Loss: 0.1741
# Train Loss: 0.2869 | Validation Loss: 0.1685
# Train Loss: 0.2855 | Validation Loss: 0.1764
# Train Loss: 0.2814 | Validation Loss: 0.1785
# Train Loss: 0.2826 | Validation Loss: 0.1790
# Train Loss: 0.2845 | Validation Loss: 0.1747
# Train Loss: 0.2796 | Validation Loss: 0.1696
# Train Loss: 0.2819 | Validation Loss: 0.1791
# Train Loss: 0.2783 | Validation Loss: 0.1754
# Training complete!
# MAE for ../processed_ds/stores_data/store-844/store-844.csv: 0.3900
#
# Processing Site: ../processed_ds/stores_data/store-560/store-560.csv
# Train size: 593 | Validation size: 148 | Test size: 186
# Train Loss: 0.9721 | Validation Loss: 0.6833
# Train Loss: 0.9570 | Validation Loss: 0.6600
# Train Loss: 0.9256 | Validation Loss: 0.6182
# Train Loss: 0.8580 | Validation Loss: 0.5409
# Train Loss: 0.7919 | Validation Loss: 0.4958
# Train Loss: 0.7235 | Validation Loss: 0.4318
# Train Loss: 0.6536 | Validation Loss: 0.3925
# Train Loss: 0.5740 | Validation Loss: 0.3211
# Train Loss: 0.4916 | Validation Loss: 0.2689
# Train Loss: 0.4000 | Validation Loss: 0.2153
# Train Loss: 0.3165 | Validation Loss: 0.1617
# Train Loss: 0.2887 | Validation Loss: 0.1590
# Train Loss: 0.2826 | Validation Loss: 0.1364
# Train Loss: 0.2822 | Validation Loss: 0.1438
# Train Loss: 0.2776 | Validation Loss: 0.1467
# Train Loss: 0.2749 | Validation Loss: 0.1484
# Train Loss: 0.2709 | Validation Loss: 0.1460
# Train Loss: 0.2701 | Validation Loss: 0.1449
# Train Loss: 0.2682 | Validation Loss: 0.1568
# Train Loss: 0.2638 | Validation Loss: 0.1549
# Train Loss: 0.2619 | Validation Loss: 0.1569
# Train Loss: 0.2618 | Validation Loss: 0.1492
# Train Loss: 0.2604 | Validation Loss: 0.1410
# Train Loss: 0.2623 | Validation Loss: 0.1315
# Train Loss: 0.2608 | Validation Loss: 0.1451
# Train Loss: 0.2571 | Validation Loss: 0.1310
# Train Loss: 0.2592 | Validation Loss: 0.1598
# Train Loss: 0.2555 | Validation Loss: 0.1388
# Train Loss: 0.2531 | Validation Loss: 0.1551
# Train Loss: 0.2495 | Validation Loss: 0.1358
# Training complete!
# MAE for ../processed_ds/stores_data/store-560/store-560.csv: 0.5523
#
# Processing Site: ../processed_ds/stores_data/store-1017/store-1017.csv
# Train size: 593 | Validation size: 148 | Test size: 186
# Train Loss: 0.9911 | Validation Loss: 0.7934
# Train Loss: 0.9698 | Validation Loss: 0.7528
# Train Loss: 0.8914 | Validation Loss: 0.5942
# Train Loss: 0.7653 | Validation Loss: 0.5115
# Train Loss: 0.6838 | Validation Loss: 0.3998
# Train Loss: 0.5631 | Validation Loss: 0.2654
# Train Loss: 0.4760 | Validation Loss: 0.2039
# Train Loss: 0.4305 | Validation Loss: 0.1679
# Train Loss: 0.3971 | Validation Loss: 0.1538
# Train Loss: 0.3818 | Validation Loss: 0.1449
# Train Loss: 0.3701 | Validation Loss: 0.1404
# Train Loss: 0.3649 | Validation Loss: 0.1462
# Train Loss: 0.3593 | Validation Loss: 0.1440
# Train Loss: 0.3559 | Validation Loss: 0.1369
# Train Loss: 0.3538 | Validation Loss: 0.1417
# Train Loss: 0.3502 | Validation Loss: 0.1402
# Train Loss: 0.3449 | Validation Loss: 0.1402
# Train Loss: 0.3432 | Validation Loss: 0.1678
# Train Loss: 0.3477 | Validation Loss: 0.1373
# Train Loss: 0.3348 | Validation Loss: 0.1429
# Train Loss: 0.3372 | Validation Loss: 0.1476
# Train Loss: 0.3387 | Validation Loss: 0.1341
# Train Loss: 0.3263 | Validation Loss: 0.1529
# Train Loss: 0.3246 | Validation Loss: 0.1471
# Train Loss: 0.3174 | Validation Loss: 0.1594
# Train Loss: 0.3136 | Validation Loss: 0.1418
# Train Loss: 0.3078 | Validation Loss: 0.1448
# Train Loss: 0.3093 | Validation Loss: 0.1412
# Train Loss: 0.3070 | Validation Loss: 0.1581
# Train Loss: 0.3015 | Validation Loss: 0.1663
# Training complete!
# MAE for ../processed_ds/stores_data/store-1017/store-1017.csv: 0.3630
#
# Processing Site: ../processed_ds/stores_data/store-1067/store-1067.csv
# Train size: 476 | Validation size: 118 | Test size: 149
# Train Loss: 1.0189 | Validation Loss: 0.7587
# Train Loss: 1.0078 | Validation Loss: 0.7480
# Train Loss: 0.9954 | Validation Loss: 0.7272
# Train Loss: 0.9715 | Validation Loss: 0.6714
# Train Loss: 0.8881 | Validation Loss: 0.5961
# Train Loss: 0.8277 | Validation Loss: 0.5565
# Train Loss: 0.7944 | Validation Loss: 0.5103
# Train Loss: 0.7381 | Validation Loss: 0.4319
# Train Loss: 0.6510 | Validation Loss: 0.3686
# Train Loss: 0.5862 | Validation Loss: 0.3416
# Train Loss: 0.5239 | Validation Loss: 0.2495
# Train Loss: 0.4852 | Validation Loss: 0.1902
# Train Loss: 0.4260 | Validation Loss: 0.1716
# Train Loss: 0.3936 | Validation Loss: 0.1809
# Train Loss: 0.3755 | Validation Loss: 0.1876
# Train Loss: 0.3695 | Validation Loss: 0.1658
# Train Loss: 0.3713 | Validation Loss: 0.1756
# Train Loss: 0.3646 | Validation Loss: 0.1882
# Train Loss: 0.3729 | Validation Loss: 0.1654
# Train Loss: 0.3697 | Validation Loss: 0.1813
# Train Loss: 0.3678 | Validation Loss: 0.1624
# Train Loss: 0.3628 | Validation Loss: 0.1634
# Train Loss: 0.3590 | Validation Loss: 0.1651
# Train Loss: 0.3615 | Validation Loss: 0.1832
# Train Loss: 0.3599 | Validation Loss: 0.1679
# Train Loss: 0.3527 | Validation Loss: 0.1509
# Train Loss: 0.3515 | Validation Loss: 0.1472
# Train Loss: 0.3525 | Validation Loss: 0.1584
# Train Loss: 0.3499 | Validation Loss: 0.1815
# Train Loss: 0.3461 | Validation Loss: 0.1637
# Training complete!
# MAE for ../processed_ds/stores_data/store-1067/store-1067.csv: 0.3585
#
# Processing Site: ../processed_ds/stores_data/store-661/store-661.csv
# Train size: 593 | Validation size: 148 | Test size: 186
# Train Loss: 1.0068 | Validation Loss: 0.6433
# Train Loss: 0.9979 | Validation Loss: 0.6352
# Train Loss: 0.9864 | Validation Loss: 0.6171
# Train Loss: 0.9515 | Validation Loss: 0.5649
# Train Loss: 0.8868 | Validation Loss: 0.5122
# Train Loss: 0.8233 | Validation Loss: 0.4527
# Train Loss: 0.7411 | Validation Loss: 0.3962
# Train Loss: 0.6517 | Validation Loss: 0.3006
# Train Loss: 0.5590 | Validation Loss: 0.2322
# Train Loss: 0.4680 | Validation Loss: 0.1512
# Train Loss: 0.3955 | Validation Loss: 0.1263
# Train Loss: 0.3718 | Validation Loss: 0.1103
# Train Loss: 0.3612 | Validation Loss: 0.1109
# Train Loss: 0.3628 | Validation Loss: 0.1250
# Train Loss: 0.3547 | Validation Loss: 0.1197
# Train Loss: 0.3497 | Validation Loss: 0.1307
# Train Loss: 0.3460 | Validation Loss: 0.1337
# Train Loss: 0.3342 | Validation Loss: 0.1494
# Train Loss: 0.3288 | Validation Loss: 0.1270
# Train Loss: 0.3255 | Validation Loss: 0.1562
# Train Loss: 0.3125 | Validation Loss: 0.1187
# Train Loss: 0.3010 | Validation Loss: 0.1374
# Train Loss: 0.2953 | Validation Loss: 0.1200
# Train Loss: 0.2809 | Validation Loss: 0.1232
# Train Loss: 0.2746 | Validation Loss: 0.1408
# Train Loss: 0.2745 | Validation Loss: 0.1195
# Train Loss: 0.2693 | Validation Loss: 0.1304
# Train Loss: 0.2661 | Validation Loss: 0.1298
# Train Loss: 0.2652 | Validation Loss: 0.1169
# Train Loss: 0.2579 | Validation Loss: 0.1298
# Training complete!
# MAE for ../processed_ds/stores_data/store-661/store-661.csv: 0.3499
#
# Processing Site: ../processed_ds/stores_data/store-188/store-188.csv
# Train size: 593 | Validation size: 148 | Test size: 186
# Train Loss: 0.9679 | Validation Loss: 0.7384
# Train Loss: 0.9512 | Validation Loss: 0.7105
# Train Loss: 0.9123 | Validation Loss: 0.6367
# Train Loss: 0.8483 | Validation Loss: 0.5855
# Train Loss: 0.7946 | Validation Loss: 0.5309
# Train Loss: 0.7525 | Validation Loss: 0.5048
# Train Loss: 0.7062 | Validation Loss: 0.4609
# Train Loss: 0.6338 | Validation Loss: 0.3981
# Train Loss: 0.5495 | Validation Loss: 0.3630
# Train Loss: 0.4778 | Validation Loss: 0.2722
# Train Loss: 0.4074 | Validation Loss: 0.2304
# Train Loss: 0.3567 | Validation Loss: 0.2014
# Train Loss: 0.3433 | Validation Loss: 0.1963
# Train Loss: 0.3389 | Validation Loss: 0.2303
# Train Loss: 0.3347 | Validation Loss: 0.2037
# Train Loss: 0.3289 | Validation Loss: 0.1962
# Train Loss: 0.3285 | Validation Loss: 0.2098
# Train Loss: 0.3311 | Validation Loss: 0.1995
# Train Loss: 0.3312 | Validation Loss: 0.2099
# Train Loss: 0.3204 | Validation Loss: 0.1867
# Train Loss: 0.3203 | Validation Loss: 0.2120
# Train Loss: 0.3247 | Validation Loss: 0.2081
# Train Loss: 0.3146 | Validation Loss: 0.2104
# Train Loss: 0.3123 | Validation Loss: 0.2181
# Train Loss: 0.3059 | Validation Loss: 0.1745
# Train Loss: 0.3036 | Validation Loss: 0.2695
# Train Loss: 0.3006 | Validation Loss: 0.1970
# Train Loss: 0.2846 | Validation Loss: 0.1958
# Train Loss: 0.2828 | Validation Loss: 0.1974
# Train Loss: 0.2800 | Validation Loss: 0.3046
# Training complete!
# MAE for ../processed_ds/stores_data/store-188/store-188.csv: 0.4211
#
# Processing Site: ../processed_ds/stores_data/store-815/store-815.csv
# Train size: 476 | Validation size: 118 | Test size: 149
# Train Loss: 1.0388 | Validation Loss: 1.2070
# Train Loss: 0.9892 | Validation Loss: 1.1204
# Train Loss: 0.9205 | Validation Loss: 1.0830
# Train Loss: 0.9125 | Validation Loss: 1.0788
# Train Loss: 0.8899 | Validation Loss: 1.0458
# Train Loss: 0.8722 | Validation Loss: 1.0075
# Train Loss: 0.8366 | Validation Loss: 0.9319
# Train Loss: 0.7934 | Validation Loss: 0.8613
# Train Loss: 0.7496 | Validation Loss: 0.8122
# Train Loss: 0.7133 | Validation Loss: 0.8013
# Train Loss: 0.6780 | Validation Loss: 0.7312
# Train Loss: 0.6520 | Validation Loss: 0.6927
# Train Loss: 0.5970 | Validation Loss: 0.5877
# Train Loss: 0.5564 | Validation Loss: 0.5212
# Train Loss: 0.5093 | Validation Loss: 0.4292
# Train Loss: 0.4468 | Validation Loss: 0.3491
# Train Loss: 0.4213 | Validation Loss: 0.3339
# Train Loss: 0.3824 | Validation Loss: 0.2921
# Train Loss: 0.3440 | Validation Loss: 0.2582
# Train Loss: 0.3340 | Validation Loss: 0.2184
# Train Loss: 0.3192 | Validation Loss: 0.2312
# Train Loss: 0.3022 | Validation Loss: 0.2055
# Train Loss: 0.2967 | Validation Loss: 0.2110
# Train Loss: 0.3084 | Validation Loss: 0.2334
# Train Loss: 0.3035 | Validation Loss: 0.2060
# Train Loss: 0.2927 | Validation Loss: 0.2167
# Train Loss: 0.2859 | Validation Loss: 0.2353
# Train Loss: 0.2890 | Validation Loss: 0.2321
# Train Loss: 0.2802 | Validation Loss: 0.2403
# Train Loss: 0.2788 | Validation Loss: 0.2459
# Training complete!
# MAE for ../processed_ds/stores_data/store-815/store-815.csv: 0.4124
#
# Processing Site: ../processed_ds/stores_data/store-539/store-539.csv
# Train size: 476 | Validation size: 118 | Test size: 149
# Train Loss: 1.0124 | Validation Loss: 0.8421
# Train Loss: 1.0061 | Validation Loss: 0.8335
# Train Loss: 0.9943 | Validation Loss: 0.8150
# Train Loss: 0.9707 | Validation Loss: 0.7762
# Train Loss: 0.9291 | Validation Loss: 0.7123
# Train Loss: 0.8740 | Validation Loss: 0.6608
# Train Loss: 0.8118 | Validation Loss: 0.5851
# Train Loss: 0.7472 | Validation Loss: 0.5270
# Train Loss: 0.6755 | Validation Loss: 0.4514
# Train Loss: 0.6061 | Validation Loss: 0.3701
# Train Loss: 0.5538 | Validation Loss: 0.3208
# Train Loss: 0.4757 | Validation Loss: 0.2292
# Train Loss: 0.3966 | Validation Loss: 0.1776
# Train Loss: 0.3398 | Validation Loss: 0.1533
# Train Loss: 0.3255 | Validation Loss: 0.1510
# Train Loss: 0.3188 | Validation Loss: 0.1605
# Train Loss: 0.3175 | Validation Loss: 0.1645
# Train Loss: 0.3197 | Validation Loss: 0.1563
# Train Loss: 0.3177 | Validation Loss: 0.1576
# Train Loss: 0.3093 | Validation Loss: 0.1721
# Train Loss: 0.3077 | Validation Loss: 0.1473
# Train Loss: 0.3095 | Validation Loss: 0.1533
# Train Loss: 0.3086 | Validation Loss: 0.1596
# Train Loss: 0.2949 | Validation Loss: 0.1640
# Train Loss: 0.3017 | Validation Loss: 0.1614
# Train Loss: 0.2990 | Validation Loss: 0.1521
# Train Loss: 0.2985 | Validation Loss: 0.1626
# Train Loss: 0.2888 | Validation Loss: 0.1521
# Train Loss: 0.2835 | Validation Loss: 0.1589
# Train Loss: 0.2923 | Validation Loss: 0.1542
# Training complete!
# MAE for ../processed_ds/stores_data/store-539/store-539.csv: 0.3155
#
# Processing Site: ../processed_ds/stores_data/store-971/store-971.csv
# Train size: 593 | Validation size: 148 | Test size: 186
# Train Loss: 0.9667 | Validation Loss: 0.6797
# Train Loss: 0.9587 | Validation Loss: 0.6615
# Train Loss: 0.9317 | Validation Loss: 0.6161
# Train Loss: 0.8690 | Validation Loss: 0.5127
# Train Loss: 0.7976 | Validation Loss: 0.4745
# Train Loss: 0.7602 | Validation Loss: 0.4418
# Train Loss: 0.7021 | Validation Loss: 0.3819
# Train Loss: 0.6120 | Validation Loss: 0.2926
# Train Loss: 0.5325 | Validation Loss: 0.2419
# Train Loss: 0.4625 | Validation Loss: 0.2003
# Train Loss: 0.4104 | Validation Loss: 0.1643
# Train Loss: 0.3809 | Validation Loss: 0.1814
# Train Loss: 0.3697 | Validation Loss: 0.1629
# Train Loss: 0.3689 | Validation Loss: 0.1570
# Train Loss: 0.3608 | Validation Loss: 0.1898
# Train Loss: 0.3450 | Validation Loss: 0.1901
# Train Loss: 0.3406 | Validation Loss: 0.2038
# Train Loss: 0.3404 | Validation Loss: 0.2115
# Train Loss: 0.3357 | Validation Loss: 0.2167
# Train Loss: 0.3295 | Validation Loss: 0.2116
# Train Loss: 0.3269 | Validation Loss: 0.2044
# Train Loss: 0.3250 | Validation Loss: 0.2087
# Train Loss: 0.3204 | Validation Loss: 0.2797
# Train Loss: 0.3185 | Validation Loss: 0.1768
# Train Loss: 0.3108 | Validation Loss: 0.1807
# Train Loss: 0.3071 | Validation Loss: 0.1831
# Train Loss: 0.2951 | Validation Loss: 0.2272
# Train Loss: 0.2865 | Validation Loss: 0.2082
# Train Loss: 0.2802 | Validation Loss: 0.1823
# Train Loss: 0.2814 | Validation Loss: 0.2505
# Training complete!
# MAE for ../processed_ds/stores_data/store-971/store-971.csv: 0.3488
#
# Processing Site: ../processed_ds/stores_data/store-299/store-299.csv
# Train size: 593 | Validation size: 148 | Test size: 186
# Train Loss: 0.9090 | Validation Loss: 0.5900
# Train Loss: 0.7720 | Validation Loss: 0.4420
# Train Loss: 0.7397 | Validation Loss: 0.4078
# Train Loss: 0.7259 | Validation Loss: 0.4177
# Train Loss: 0.7161 | Validation Loss: 0.3990
# Train Loss: 0.7147 | Validation Loss: 0.4249
# Train Loss: 0.7059 | Validation Loss: 0.3880
# Train Loss: 0.7012 | Validation Loss: 0.3970
# Train Loss: 0.6874 | Validation Loss: 0.3798
# Train Loss: 0.6729 | Validation Loss: 0.3685
# Train Loss: 0.6616 | Validation Loss: 0.3708
# Train Loss: 0.6527 | Validation Loss: 0.3804
# Train Loss: 0.6422 | Validation Loss: 0.3489
# Train Loss: 0.6103 | Validation Loss: 0.3422
# Train Loss: 0.5946 | Validation Loss: 0.3160
# Train Loss: 0.5787 | Validation Loss: 0.3211
# Train Loss: 0.5504 | Validation Loss: 0.3000
# Train Loss: 0.5266 | Validation Loss: 0.2875
# Train Loss: 0.5010 | Validation Loss: 0.2877
# Train Loss: 0.4747 | Validation Loss: 0.2860
# Train Loss: 0.4481 | Validation Loss: 0.2974
# Train Loss: 0.4193 | Validation Loss: 0.2505
# Train Loss: 0.3893 | Validation Loss: 0.2419
# Train Loss: 0.3671 | Validation Loss: 0.2238
# Train Loss: 0.3318 | Validation Loss: 0.2196
# Train Loss: 0.3066 | Validation Loss: 0.1916
# Train Loss: 0.2856 | Validation Loss: 0.2617
# Train Loss: 0.2792 | Validation Loss: 0.2240
# Train Loss: 0.2727 | Validation Loss: 0.2288
# Train Loss: 0.2675 | Validation Loss: 0.2293
# Training complete!
# MAE for ../processed_ds/stores_data/store-299/store-299.csv: 0.3932
#
# Processing Site: ../processed_ds/stores_data/store-451/store-451.csv
# Train size: 593 | Validation size: 148 | Test size: 186
# Train Loss: 0.9834 | Validation Loss: 0.7896
# Train Loss: 0.9690 | Validation Loss: 0.7640
# Train Loss: 0.9240 | Validation Loss: 0.6830
# Train Loss: 0.8291 | Validation Loss: 0.6066
# Train Loss: 0.7474 | Validation Loss: 0.5058
# Train Loss: 0.6197 | Validation Loss: 0.3605
# Train Loss: 0.5034 | Validation Loss: 0.2728
# Train Loss: 0.4111 | Validation Loss: 0.1948
# Train Loss: 0.3487 | Validation Loss: 0.1523
# Train Loss: 0.3194 | Validation Loss: 0.1420
# Train Loss: 0.3143 | Validation Loss: 0.1503
# Train Loss: 0.3122 | Validation Loss: 0.1408
# Train Loss: 0.3081 | Validation Loss: 0.1379
# Train Loss: 0.3078 | Validation Loss: 0.1394
# Train Loss: 0.3055 | Validation Loss: 0.1356
# Train Loss: 0.3030 | Validation Loss: 0.1361
# Train Loss: 0.2989 | Validation Loss: 0.1439
# Train Loss: 0.2955 | Validation Loss: 0.1423
# Train Loss: 0.2997 | Validation Loss: 0.1532
# Train Loss: 0.2982 | Validation Loss: 0.1399
# Train Loss: 0.2970 | Validation Loss: 0.1411
# Train Loss: 0.2915 | Validation Loss: 0.1393
# Train Loss: 0.2911 | Validation Loss: 0.1385
# Train Loss: 0.2874 | Validation Loss: 0.1606
# Train Loss: 0.2850 | Validation Loss: 0.1451
# Train Loss: 0.2829 | Validation Loss: 0.1529
# Train Loss: 0.2881 | Validation Loss: 0.1499
# Train Loss: 0.2848 | Validation Loss: 0.1657
# Train Loss: 0.2809 | Validation Loss: 0.1572
# Train Loss: 0.2762 | Validation Loss: 0.1376
# Training complete!
# MAE for ../processed_ds/stores_data/store-451/store-451.csv: 0.3429
#
# Processing Site: ../processed_ds/stores_data/store-722/store-722.csv
# Train size: 593 | Validation size: 148 | Test size: 186
# Train Loss: 0.9886 | Validation Loss: 0.7481
# Train Loss: 0.9707 | Validation Loss: 0.7190
# Train Loss: 0.9113 | Validation Loss: 0.6110
# Train Loss: 0.8061 | Validation Loss: 0.5358
# Train Loss: 0.7289 | Validation Loss: 0.4419
# Train Loss: 0.5938 | Validation Loss: 0.2918
# Train Loss: 0.4585 | Validation Loss: 0.1883
# Train Loss: 0.3601 | Validation Loss: 0.1222
# Train Loss: 0.3119 | Validation Loss: 0.1214
# Train Loss: 0.3015 | Validation Loss: 0.1129
# Train Loss: 0.2984 | Validation Loss: 0.1132
# Train Loss: 0.2993 | Validation Loss: 0.1143
# Train Loss: 0.2926 | Validation Loss: 0.1139
# Train Loss: 0.2904 | Validation Loss: 0.1136
# Train Loss: 0.2930 | Validation Loss: 0.1092
# Train Loss: 0.2870 | Validation Loss: 0.1149
# Train Loss: 0.2851 | Validation Loss: 0.1040
# Train Loss: 0.2832 | Validation Loss: 0.1080
# Train Loss: 0.2828 | Validation Loss: 0.1090
# Train Loss: 0.2808 | Validation Loss: 0.1179
# Train Loss: 0.2799 | Validation Loss: 0.1184
# Train Loss: 0.2757 | Validation Loss: 0.1113
# Train Loss: 0.2717 | Validation Loss: 0.1081
# Train Loss: 0.2736 | Validation Loss: 0.1218
# Train Loss: 0.2732 | Validation Loss: 0.1088
# Train Loss: 0.2689 | Validation Loss: 0.1139
# Train Loss: 0.2689 | Validation Loss: 0.1209
# Train Loss: 0.2662 | Validation Loss: 0.1140
# Train Loss: 0.2714 | Validation Loss: 0.1316
# Train Loss: 0.2678 | Validation Loss: 0.1052
# Training complete!
# MAE for ../processed_ds/stores_data/store-722/store-722.csv: 0.3379
#
# Processing Site: ../processed_ds/stores_data/store-351/store-351.csv
# Train size: 593 | Validation size: 148 | Test size: 186
# Train Loss: 0.9829 | Validation Loss: 0.7167
# Train Loss: 0.9634 | Validation Loss: 0.6869
# Train Loss: 0.9090 | Validation Loss: 0.6131
# Train Loss: 0.8158 | Validation Loss: 0.5607
# Train Loss: 0.7618 | Validation Loss: 0.5098
# Train Loss: 0.6811 | Validation Loss: 0.4233
# Train Loss: 0.5603 | Validation Loss: 0.3237
# Train Loss: 0.4553 | Validation Loss: 0.2505
# Train Loss: 0.3825 | Validation Loss: 0.2125
# Train Loss: 0.3457 | Validation Loss: 0.1783
# Train Loss: 0.3351 | Validation Loss: 0.1907
# Train Loss: 0.3260 | Validation Loss: 0.1809
# Train Loss: 0.3256 | Validation Loss: 0.2297
# Train Loss: 0.3294 | Validation Loss: 0.1820
# Train Loss: 0.3223 | Validation Loss: 0.1973
# Train Loss: 0.3197 | Validation Loss: 0.1921
# Train Loss: 0.3223 | Validation Loss: 0.1870
# Train Loss: 0.3172 | Validation Loss: 0.1825
# Train Loss: 0.3157 | Validation Loss: 0.2127
# Train Loss: 0.3193 | Validation Loss: 0.1726
# Train Loss: 0.3104 | Validation Loss: 0.1808
# Train Loss: 0.3061 | Validation Loss: 0.2017
# Train Loss: 0.3028 | Validation Loss: 0.1960
# Train Loss: 0.2983 | Validation Loss: 0.1866
# Train Loss: 0.2980 | Validation Loss: 0.1793
# Train Loss: 0.2945 | Validation Loss: 0.2531
# Train Loss: 0.2866 | Validation Loss: 0.2270
# Train Loss: 0.2917 | Validation Loss: 0.2175
# Train Loss: 0.2846 | Validation Loss: 0.2231
# Train Loss: 0.2830 | Validation Loss: 0.2424
# Training complete!
# MAE for ../processed_ds/stores_data/store-351/store-351.csv: 0.3642
#
# Processing Site: ../processed_ds/stores_data/store-349/store-349.csv
# Train size: 593 | Validation size: 148 | Test size: 186
# Train Loss: 0.9965 | Validation Loss: 0.7055
# Train Loss: 0.9766 | Validation Loss: 0.6751
# Train Loss: 0.9181 | Validation Loss: 0.5854
# Train Loss: 0.8277 | Validation Loss: 0.5292
# Train Loss: 0.7249 | Validation Loss: 0.4160
# Train Loss: 0.5665 | Validation Loss: 0.3084
# Train Loss: 0.4239 | Validation Loss: 0.2277
# Train Loss: 0.3147 | Validation Loss: 0.1697
# Train Loss: 0.2696 | Validation Loss: 0.1593
# Train Loss: 0.2612 | Validation Loss: 0.1602
# Train Loss: 0.2600 | Validation Loss: 0.1658
# Train Loss: 0.2586 | Validation Loss: 0.1530
# Train Loss: 0.2572 | Validation Loss: 0.1539
# Train Loss: 0.2558 | Validation Loss: 0.1671
# Train Loss: 0.2540 | Validation Loss: 0.1596
# Train Loss: 0.2536 | Validation Loss: 0.1649
# Train Loss: 0.2553 | Validation Loss: 0.1674
# Train Loss: 0.2533 | Validation Loss: 0.1557
# Train Loss: 0.2524 | Validation Loss: 0.1684
# Train Loss: 0.2514 | Validation Loss: 0.1676
# Train Loss: 0.2503 | Validation Loss: 0.1588
# Train Loss: 0.2501 | Validation Loss: 0.1523
# Train Loss: 0.2511 | Validation Loss: 0.1695
# Train Loss: 0.2534 | Validation Loss: 0.1554
# Train Loss: 0.2529 | Validation Loss: 0.1665
# Train Loss: 0.2491 | Validation Loss: 0.1524
# Train Loss: 0.2475 | Validation Loss: 0.1490
# Train Loss: 0.2496 | Validation Loss: 0.1550
# Train Loss: 0.2506 | Validation Loss: 0.1553
# Train Loss: 0.2490 | Validation Loss: 0.1553
# Training complete!
# MAE for ../processed_ds/stores_data/store-349/store-349.csv: 1.3215
#
# Processing Site: ../processed_ds/stores_data/store-700/store-700.csv
# Train size: 593 | Validation size: 148 | Test size: 186
# Train Loss: 0.9616 | Validation Loss: 0.8286
# Train Loss: 0.9304 | Validation Loss: 0.7667
# Train Loss: 0.8160 | Validation Loss: 0.6003
# Train Loss: 0.6813 | Validation Loss: 0.5108
# Train Loss: 0.5620 | Validation Loss: 0.3275
# Train Loss: 0.4165 | Validation Loss: 0.2180
# Train Loss: 0.3556 | Validation Loss: 0.1704
# Train Loss: 0.3260 | Validation Loss: 0.1485
# Train Loss: 0.3059 | Validation Loss: 0.1467
# Train Loss: 0.3019 | Validation Loss: 0.1395
# Train Loss: 0.2973 | Validation Loss: 0.1441
# Train Loss: 0.2913 | Validation Loss: 0.1426
# Train Loss: 0.2895 | Validation Loss: 0.1327
# Train Loss: 0.2924 | Validation Loss: 0.1372
# Train Loss: 0.2832 | Validation Loss: 0.1472
# Train Loss: 0.2872 | Validation Loss: 0.1399
# Train Loss: 0.2814 | Validation Loss: 0.1409
# Train Loss: 0.2758 | Validation Loss: 0.1401
# Train Loss: 0.2779 | Validation Loss: 0.1457
# Train Loss: 0.2762 | Validation Loss: 0.1446
# Train Loss: 0.2739 | Validation Loss: 0.1590
# Train Loss: 0.2712 | Validation Loss: 0.1321
# Train Loss: 0.2674 | Validation Loss: 0.1433
# Train Loss: 0.2669 | Validation Loss: 0.1500
# Train Loss: 0.2679 | Validation Loss: 0.1430
# Train Loss: 0.2559 | Validation Loss: 0.1394
# Train Loss: 0.2557 | Validation Loss: 0.1326
# Train Loss: 0.2513 | Validation Loss: 0.1460
# Train Loss: 0.2538 | Validation Loss: 0.1351
# Train Loss: 0.2535 | Validation Loss: 0.1424
# Training complete!
# MAE for ../processed_ds/stores_data/store-700/store-700.csv: 0.9735
#
# Processing Site: ../processed_ds/stores_data/store-610/store-610.csv
# Train size: 593 | Validation size: 148 | Test size: 186
# Train Loss: 0.9856 | Validation Loss: 0.8555
# Train Loss: 0.9596 | Validation Loss: 0.8100
# Train Loss: 0.8967 | Validation Loss: 0.6861
# Train Loss: 0.7746 | Validation Loss: 0.5501
# Train Loss: 0.6966 | Validation Loss: 0.4840
# Train Loss: 0.5891 | Validation Loss: 0.3173
# Train Loss: 0.4384 | Validation Loss: 0.2284
# Train Loss: 0.3703 | Validation Loss: 0.1951
# Train Loss: 0.3284 | Validation Loss: 0.1720
# Train Loss: 0.3044 | Validation Loss: 0.2004
# Train Loss: 0.3023 | Validation Loss: 0.1816
# Train Loss: 0.2982 | Validation Loss: 0.1696
# Train Loss: 0.2993 | Validation Loss: 0.1625
# Train Loss: 0.2971 | Validation Loss: 0.1598
# Train Loss: 0.2923 | Validation Loss: 0.1605
# Train Loss: 0.2872 | Validation Loss: 0.1653
# Train Loss: 0.2937 | Validation Loss: 0.1624
# Train Loss: 0.2938 | Validation Loss: 0.1604
# Train Loss: 0.2909 | Validation Loss: 0.1578
# Train Loss: 0.2853 | Validation Loss: 0.1654
# Train Loss: 0.2869 | Validation Loss: 0.1682
# Train Loss: 0.2857 | Validation Loss: 0.1511
# Train Loss: 0.2814 | Validation Loss: 0.1561
# Train Loss: 0.2815 | Validation Loss: 0.1642
# Train Loss: 0.2792 | Validation Loss: 0.1547
# Train Loss: 0.2817 | Validation Loss: 0.1525
# Train Loss: 0.2807 | Validation Loss: 0.1572
# Train Loss: 0.2812 | Validation Loss: 0.1710
# Train Loss: 0.2770 | Validation Loss: 0.1657
# Train Loss: 0.2778 | Validation Loss: 0.1681
# Training complete!
# MAE for ../processed_ds/stores_data/store-610/store-610.csv: 0.3518
#
# Processing Site: ../processed_ds/stores_data/store-96/store-96.csv
# Train size: 593 | Validation size: 148 | Test size: 186
# Train Loss: 0.9621 | Validation Loss: 0.7558
# Train Loss: 0.9141 | Validation Loss: 0.6612
# Train Loss: 0.7493 | Validation Loss: 0.5011
# Train Loss: 0.5898 | Validation Loss: 0.3875
# Train Loss: 0.4649 | Validation Loss: 0.2310
# Train Loss: 0.3554 | Validation Loss: 0.1735
# Train Loss: 0.3168 | Validation Loss: 0.1512
# Train Loss: 0.2960 | Validation Loss: 0.1361
# Train Loss: 0.2781 | Validation Loss: 0.1323
# Train Loss: 0.2759 | Validation Loss: 0.1203
# Train Loss: 0.2674 | Validation Loss: 0.1211
# Train Loss: 0.2664 | Validation Loss: 0.1264
# Train Loss: 0.2662 | Validation Loss: 0.1198
# Train Loss: 0.2641 | Validation Loss: 0.1196
# Train Loss: 0.2623 | Validation Loss: 0.1332
# Train Loss: 0.2584 | Validation Loss: 0.1231
# Train Loss: 0.2541 | Validation Loss: 0.1213
# Train Loss: 0.2545 | Validation Loss: 0.1283
# Train Loss: 0.2546 | Validation Loss: 0.1206
# Train Loss: 0.2509 | Validation Loss: 0.1262
# Train Loss: 0.2506 | Validation Loss: 0.1135
# Train Loss: 0.2522 | Validation Loss: 0.1202
# Train Loss: 0.2496 | Validation Loss: 0.1215
# Train Loss: 0.2480 | Validation Loss: 0.1145
# Train Loss: 0.2445 | Validation Loss: 0.1198
# Train Loss: 0.2413 | Validation Loss: 0.1408
# Train Loss: 0.2413 | Validation Loss: 0.1255
# Train Loss: 0.2368 | Validation Loss: 0.1156
# Train Loss: 0.2384 | Validation Loss: 0.1098
# Train Loss: 0.2376 | Validation Loss: 0.1204
# Training complete!
# MAE for ../processed_ds/stores_data/store-96/store-96.csv: 0.3013
#
# Processing Site: ../processed_ds/stores_data/store-792/store-792.csv
# Train size: 593 | Validation size: 148 | Test size: 186
# Train Loss: 0.9682 | Validation Loss: 0.8408
# Train Loss: 0.9388 | Validation Loss: 0.7782
# Train Loss: 0.8638 | Validation Loss: 0.6480
# Train Loss: 0.7341 | Validation Loss: 0.5282
# Train Loss: 0.6547 | Validation Loss: 0.4543
# Train Loss: 0.5561 | Validation Loss: 0.3476
# Train Loss: 0.4577 | Validation Loss: 0.2633
# Train Loss: 0.4006 | Validation Loss: 0.2214
# Train Loss: 0.3598 | Validation Loss: 0.1871
# Train Loss: 0.3377 | Validation Loss: 0.1598
# Train Loss: 0.3375 | Validation Loss: 0.1629
# Train Loss: 0.3230 | Validation Loss: 0.1676
# Train Loss: 0.3214 | Validation Loss: 0.1867
# Train Loss: 0.3204 | Validation Loss: 0.1590
# Train Loss: 0.3187 | Validation Loss: 0.1610
# Train Loss: 0.3159 | Validation Loss: 0.1758
# Train Loss: 0.3101 | Validation Loss: 0.1680
# Train Loss: 0.3067 | Validation Loss: 0.1729
# Train Loss: 0.3118 | Validation Loss: 0.2120
# Train Loss: 0.3097 | Validation Loss: 0.1547
# Train Loss: 0.3024 | Validation Loss: 0.1526
# Train Loss: 0.3023 | Validation Loss: 0.1654
# Train Loss: 0.3003 | Validation Loss: 0.1540
# Train Loss: 0.2958 | Validation Loss: 0.2119
# Train Loss: 0.2965 | Validation Loss: 0.1890
# Train Loss: 0.2915 | Validation Loss: 0.2744
# Train Loss: 0.2922 | Validation Loss: 0.1687
# Train Loss: 0.2854 | Validation Loss: 0.1792
# Train Loss: 0.2790 | Validation Loss: 0.1638
# Train Loss: 0.2777 | Validation Loss: 0.2171
# Training complete!
# MAE for ../processed_ds/stores_data/store-792/store-792.csv: 0.3871
#
# Processing Site: ../processed_ds/stores_data/store-913/store-913.csv
# Train size: 593 | Validation size: 148 | Test size: 186
# Train Loss: 0.9700 | Validation Loss: 0.8855
# Train Loss: 0.9484 | Validation Loss: 0.8360
# Train Loss: 0.9032 | Validation Loss: 0.7241
# Train Loss: 0.8096 | Validation Loss: 0.5848
# Train Loss: 0.7298 | Validation Loss: 0.5428
# Train Loss: 0.6619 | Validation Loss: 0.4269
# Train Loss: 0.5525 | Validation Loss: 0.3188
# Train Loss: 0.4683 | Validation Loss: 0.2492
# Train Loss: 0.4018 | Validation Loss: 0.2016
# Train Loss: 0.3667 | Validation Loss: 0.1852
# Train Loss: 0.3594 | Validation Loss: 0.1925
# Train Loss: 0.3621 | Validation Loss: 0.1840
# Train Loss: 0.3543 | Validation Loss: 0.1676
# Train Loss: 0.3468 | Validation Loss: 0.1828
# Train Loss: 0.3442 | Validation Loss: 0.1742
# Train Loss: 0.3526 | Validation Loss: 0.1705
# Train Loss: 0.3483 | Validation Loss: 0.1712
# Train Loss: 0.3411 | Validation Loss: 0.1674
# Train Loss: 0.3403 | Validation Loss: 0.1778
# Train Loss: 0.3429 | Validation Loss: 0.1825
# Train Loss: 0.3422 | Validation Loss: 0.1860
# Train Loss: 0.3418 | Validation Loss: 0.1576
# Train Loss: 0.3329 | Validation Loss: 0.1732
# Train Loss: 0.3323 | Validation Loss: 0.1749
# Train Loss: 0.3324 | Validation Loss: 0.1618
# Train Loss: 0.3294 | Validation Loss: 0.1804
# Train Loss: 0.3397 | Validation Loss: 0.1848
# Train Loss: 0.3327 | Validation Loss: 0.1735
# Train Loss: 0.3244 | Validation Loss: 0.1772
# Train Loss: 0.3228 | Validation Loss: 0.1710
# Training complete!
# MAE for ../processed_ds/stores_data/store-913/store-913.csv: 0.5100
#
# Processing Site: ../processed_ds/stores_data/store-885/store-885.csv
# Train size: 593 | Validation size: 148 | Test size: 186
# Train Loss: 1.0123 | Validation Loss: 0.7518
# Train Loss: 0.9912 | Validation Loss: 0.7118
# Train Loss: 0.9096 | Validation Loss: 0.5693
# Train Loss: 0.7746 | Validation Loss: 0.4185
# Train Loss: 0.6961 | Validation Loss: 0.3479
# Train Loss: 0.5707 | Validation Loss: 0.2848
# Train Loss: 0.4689 | Validation Loss: 0.2433
# Train Loss: 0.3914 | Validation Loss: 0.1768
# Train Loss: 0.3358 | Validation Loss: 0.1956
# Train Loss: 0.3219 | Validation Loss: 0.1465
# Train Loss: 0.3138 | Validation Loss: 0.1617
# Train Loss: 0.3106 | Validation Loss: 0.1373
# Train Loss: 0.3099 | Validation Loss: 0.1355
# Train Loss: 0.3106 | Validation Loss: 0.1212
# Train Loss: 0.3070 | Validation Loss: 0.1563
# Train Loss: 0.3153 | Validation Loss: 0.1376
# Train Loss: 0.3041 | Validation Loss: 0.1184
# Train Loss: 0.3050 | Validation Loss: 0.1307
# Train Loss: 0.3011 | Validation Loss: 0.1163
# Train Loss: 0.3003 | Validation Loss: 0.1243
# Train Loss: 0.2990 | Validation Loss: 0.1514
# Train Loss: 0.2984 | Validation Loss: 0.1202
# Train Loss: 0.2974 | Validation Loss: 0.1280
# Train Loss: 0.2924 | Validation Loss: 0.1191
# Train Loss: 0.2882 | Validation Loss: 0.1310
# Train Loss: 0.2852 | Validation Loss: 0.1535
# Train Loss: 0.2848 | Validation Loss: 0.1440
# Train Loss: 0.2906 | Validation Loss: 0.1333
# Train Loss: 0.2877 | Validation Loss: 0.1373
# Train Loss: 0.2848 | Validation Loss: 0.1407
# Training complete!
# MAE for ../processed_ds/stores_data/store-885/store-885.csv: 0.3237
#
# Processing Site: ../processed_ds/stores_data/store-636/store-636.csv
# Train size: 476 | Validation size: 118 | Test size: 149
# Train Loss: 0.9732 | Validation Loss: 0.6870
# Train Loss: 0.9557 | Validation Loss: 0.6548
# Train Loss: 0.9048 | Validation Loss: 0.5394
# Train Loss: 0.8466 | Validation Loss: 0.5041
# Train Loss: 0.8151 | Validation Loss: 0.4505
# Train Loss: 0.7781 | Validation Loss: 0.4179
# Train Loss: 0.7493 | Validation Loss: 0.3972
# Train Loss: 0.7239 | Validation Loss: 0.3960
# Train Loss: 0.7086 | Validation Loss: 0.3870
# Train Loss: 0.6869 | Validation Loss: 0.3734
# Train Loss: 0.6559 | Validation Loss: 0.3551
# Train Loss: 0.6224 | Validation Loss: 0.3186
# Train Loss: 0.5793 | Validation Loss: 0.2744
# Train Loss: 0.5332 | Validation Loss: 0.2549
# Train Loss: 0.4973 | Validation Loss: 0.1962
# Train Loss: 0.4581 | Validation Loss: 0.1716
# Train Loss: 0.4264 | Validation Loss: 0.1373
# Train Loss: 0.3973 | Validation Loss: 0.1269
# Train Loss: 0.3674 | Validation Loss: 0.1713
# Train Loss: 0.3403 | Validation Loss: 0.1572
# Train Loss: 0.3350 | Validation Loss: 0.3336
# Train Loss: 0.3209 | Validation Loss: 0.3444
# Train Loss: 0.3128 | Validation Loss: 0.3237
# Train Loss: 0.3139 | Validation Loss: 0.7167
# Train Loss: 0.3000 | Validation Loss: 0.3597
# Train Loss: 0.3093 | Validation Loss: 0.1516
# Train Loss: 0.3062 | Validation Loss: 0.6015
# Train Loss: 0.2965 | Validation Loss: 0.2552
# Train Loss: 0.2879 | Validation Loss: 0.3658
# Train Loss: 0.2838 | Validation Loss: 0.3119
# Training complete!
# MAE for ../processed_ds/stores_data/store-636/store-636.csv: 0.3857
#
# Processing Site: ../processed_ds/stores_data/store-296/store-296.csv
# Train size: 593 | Validation size: 148 | Test size: 186
# Train Loss: 0.9786 | Validation Loss: 0.7439
# Train Loss: 0.9523 | Validation Loss: 0.6940
# Train Loss: 0.8474 | Validation Loss: 0.5399
# Train Loss: 0.7154 | Validation Loss: 0.4601
# Train Loss: 0.5949 | Validation Loss: 0.3021
# Train Loss: 0.4496 | Validation Loss: 0.1944
# Train Loss: 0.3764 | Validation Loss: 0.1421
# Train Loss: 0.3306 | Validation Loss: 0.1199
# Train Loss: 0.3152 | Validation Loss: 0.1127
# Train Loss: 0.3105 | Validation Loss: 0.1255
# Train Loss: 0.3069 | Validation Loss: 0.1168
# Train Loss: 0.3022 | Validation Loss: 0.1154
# Train Loss: 0.3012 | Validation Loss: 0.1177
# Train Loss: 0.2993 | Validation Loss: 0.1163
# Train Loss: 0.2988 | Validation Loss: 0.1123
# Train Loss: 0.2990 | Validation Loss: 0.1206
# Train Loss: 0.2919 | Validation Loss: 0.1298
# Train Loss: 0.3045 | Validation Loss: 0.1051
# Train Loss: 0.2950 | Validation Loss: 0.1170
# Train Loss: 0.2926 | Validation Loss: 0.1062
# Train Loss: 0.2890 | Validation Loss: 0.1091
# Train Loss: 0.2866 | Validation Loss: 0.1428
# Train Loss: 0.2864 | Validation Loss: 0.1339
# Train Loss: 0.2831 | Validation Loss: 0.1199
# Train Loss: 0.2836 | Validation Loss: 0.1371
# Train Loss: 0.2792 | Validation Loss: 0.1191
# Train Loss: 0.2759 | Validation Loss: 0.1046
# Train Loss: 0.2724 | Validation Loss: 0.1175
# Train Loss: 0.2689 | Validation Loss: 0.1143
# Train Loss: 0.2669 | Validation Loss: 0.1253
# Training complete!
# MAE for ../processed_ds/stores_data/store-296/store-296.csv: 0.3805
#
# Processing Site: ../processed_ds/stores_data/store-848/store-848.csv
# Train size: 593 | Validation size: 148 | Test size: 186
# Train Loss: 0.9894 | Validation Loss: 0.5704
# Train Loss: 0.9743 | Validation Loss: 0.5637
# Train Loss: 0.9477 | Validation Loss: 0.5583
# Train Loss: 0.8957 | Validation Loss: 0.5131
# Train Loss: 0.8004 | Validation Loss: 0.4669
# Train Loss: 0.7331 | Validation Loss: 0.4532
# Train Loss: 0.6939 | Validation Loss: 0.4115
# Train Loss: 0.6498 | Validation Loss: 0.4156
# Train Loss: 0.5801 | Validation Loss: 0.3431
# Train Loss: 0.5103 | Validation Loss: 0.3276
# Train Loss: 0.4656 | Validation Loss: 0.2268
# Train Loss: 0.4255 | Validation Loss: 0.2205
# Train Loss: 0.3880 | Validation Loss: 0.1495
# Train Loss: 0.3612 | Validation Loss: 0.2166
# Train Loss: 0.3403 | Validation Loss: 0.1657
# Train Loss: 0.3312 | Validation Loss: 0.2306
# Train Loss: 0.3292 | Validation Loss: 0.1806
# Train Loss: 0.3193 | Validation Loss: 0.1698
# Train Loss: 0.3090 | Validation Loss: 0.1725
# Train Loss: 0.3037 | Validation Loss: 0.2005
# Train Loss: 0.2999 | Validation Loss: 0.1781
# Train Loss: 0.2991 | Validation Loss: 0.1967
# Train Loss: 0.2985 | Validation Loss: 0.2066
# Train Loss: 0.2907 | Validation Loss: 0.1884
# Train Loss: 0.2825 | Validation Loss: 0.1614
# Train Loss: 0.2791 | Validation Loss: 0.1367
# Train Loss: 0.2823 | Validation Loss: 0.2149
# Train Loss: 0.2830 | Validation Loss: 0.1995
# Train Loss: 0.2782 | Validation Loss: 0.2101
# Train Loss: 0.2679 | Validation Loss: 0.1816
# Training complete!
# MAE for ../processed_ds/stores_data/store-848/store-848.csv: 0.4057
#
# Processing Site: ../processed_ds/stores_data/store-596/store-596.csv
# Train size: 593 | Validation size: 148 | Test size: 186
# Train Loss: 0.9760 | Validation Loss: 0.7299
# Train Loss: 0.9600 | Validation Loss: 0.7093
# Train Loss: 0.9236 | Validation Loss: 0.6321
# Train Loss: 0.8307 | Validation Loss: 0.5354
# Train Loss: 0.7633 | Validation Loss: 0.4621
# Train Loss: 0.6499 | Validation Loss: 0.3330
# Train Loss: 0.5052 | Validation Loss: 0.2250
# Train Loss: 0.4094 | Validation Loss: 0.1411
# Train Loss: 0.3364 | Validation Loss: 0.1084
# Train Loss: 0.3006 | Validation Loss: 0.1034
# Train Loss: 0.2938 | Validation Loss: 0.1051
# Train Loss: 0.2886 | Validation Loss: 0.1078
# Train Loss: 0.2842 | Validation Loss: 0.1094
# Train Loss: 0.2794 | Validation Loss: 0.1057
# Train Loss: 0.2758 | Validation Loss: 0.1024
# Train Loss: 0.2728 | Validation Loss: 0.1187
# Train Loss: 0.2755 | Validation Loss: 0.1033
# Train Loss: 0.2677 | Validation Loss: 0.1096
# Train Loss: 0.2738 | Validation Loss: 0.0997
# Train Loss: 0.2691 | Validation Loss: 0.1086
# Train Loss: 0.2650 | Validation Loss: 0.1172
# Train Loss: 0.2657 | Validation Loss: 0.1131
# Train Loss: 0.2611 | Validation Loss: 0.1257
# Train Loss: 0.2640 | Validation Loss: 0.1079
# Train Loss: 0.2578 | Validation Loss: 0.1087
# Train Loss: 0.2576 | Validation Loss: 0.1126
# Train Loss: 0.2552 | Validation Loss: 0.1189
# Train Loss: 0.2554 | Validation Loss: 0.1106
# Train Loss: 0.2528 | Validation Loss: 0.1099
# Train Loss: 0.2541 | Validation Loss: 0.1065
# Training complete!
# MAE for ../processed_ds/stores_data/store-596/store-596.csv: 0.3349
#
# Processing Site: ../processed_ds/stores_data/store-547/store-547.csv
# Train size: 476 | Validation size: 118 | Test size: 149
# Train Loss: 1.0148 | Validation Loss: 0.8400
# Train Loss: 1.0091 | Validation Loss: 0.8315
# Train Loss: 0.9928 | Validation Loss: 0.8121
# Train Loss: 0.9547 | Validation Loss: 0.7560
# Train Loss: 0.8985 | Validation Loss: 0.6989
# Train Loss: 0.8407 | Validation Loss: 0.6492
# Train Loss: 0.7996 | Validation Loss: 0.5861
# Train Loss: 0.7311 | Validation Loss: 0.4942
# Train Loss: 0.6437 | Validation Loss: 0.3825
# Train Loss: 0.5661 | Validation Loss: 0.3094
# Train Loss: 0.5108 | Validation Loss: 0.2640
# Train Loss: 0.4547 | Validation Loss: 0.2039
# Train Loss: 0.4061 | Validation Loss: 0.2250
# Train Loss: 0.3877 | Validation Loss: 0.1663
# Train Loss: 0.3905 | Validation Loss: 0.1764
# Train Loss: 0.3891 | Validation Loss: 0.1877
# Train Loss: 0.3836 | Validation Loss: 0.1942
# Train Loss: 0.3768 | Validation Loss: 0.1933
# Train Loss: 0.3756 | Validation Loss: 0.1774
# Train Loss: 0.3797 | Validation Loss: 0.1985
# Train Loss: 0.3724 | Validation Loss: 0.1709
# Train Loss: 0.3700 | Validation Loss: 0.1922
# Train Loss: 0.3668 | Validation Loss: 0.1889
# Train Loss: 0.3675 | Validation Loss: 0.1915
# Train Loss: 0.3660 | Validation Loss: 0.1898
# Train Loss: 0.3692 | Validation Loss: 0.2045
# Train Loss: 0.3606 | Validation Loss: 0.2169
# Train Loss: 0.3585 | Validation Loss: 0.1883
# Train Loss: 0.3594 | Validation Loss: 0.2040
# Train Loss: 0.3585 | Validation Loss: 0.1925
# Training complete!
# MAE for ../processed_ds/stores_data/store-547/store-547.csv: 0.3920
#
# Processing Site: ../processed_ds/stores_data/store-7/store-7.csv
# Train size: 593 | Validation size: 148 | Test size: 186
# Train Loss: 0.9614 | Validation Loss: 0.7921
# Train Loss: 0.9363 | Validation Loss: 0.7516
# Train Loss: 0.8581 | Validation Loss: 0.5823
# Train Loss: 0.7294 | Validation Loss: 0.4934
# Train Loss: 0.6276 | Validation Loss: 0.3443
# Train Loss: 0.4592 | Validation Loss: 0.2129
# Train Loss: 0.3643 | Validation Loss: 0.1641
# Train Loss: 0.3152 | Validation Loss: 0.1353
# Train Loss: 0.2917 | Validation Loss: 0.1299
# Train Loss: 0.2795 | Validation Loss: 0.1255
# Train Loss: 0.2760 | Validation Loss: 0.1257
# Train Loss: 0.2728 | Validation Loss: 0.1276
# Train Loss: 0.2728 | Validation Loss: 0.1367
# Train Loss: 0.2697 | Validation Loss: 0.1271
# Train Loss: 0.2678 | Validation Loss: 0.1222
# Train Loss: 0.2654 | Validation Loss: 0.1210
# Train Loss: 0.2627 | Validation Loss: 0.1215
# Train Loss: 0.2606 | Validation Loss: 0.1219
# Train Loss: 0.2608 | Validation Loss: 0.1303
# Train Loss: 0.2600 | Validation Loss: 0.1227
# Train Loss: 0.2567 | Validation Loss: 0.1226
# Train Loss: 0.2561 | Validation Loss: 0.1230
# Train Loss: 0.2561 | Validation Loss: 0.1216
# Train Loss: 0.2504 | Validation Loss: 0.1166
# Train Loss: 0.2470 | Validation Loss: 0.1249
# Train Loss: 0.2463 | Validation Loss: 0.1259
# Train Loss: 0.2453 | Validation Loss: 0.1239
# Train Loss: 0.2430 | Validation Loss: 0.1242
# Train Loss: 0.2457 | Validation Loss: 0.1297
# Train Loss: 0.2392 | Validation Loss: 0.1240
# Training complete!
# MAE for ../processed_ds/stores_data/store-7/store-7.csv: 0.3360
#
# Processing Site: ../processed_ds/stores_data/store-94/store-94.csv
# Train size: 593 | Validation size: 148 | Test size: 186
# Train Loss: 0.9741 | Validation Loss: 0.7690
# Train Loss: 0.9468 | Validation Loss: 0.7229
# Train Loss: 0.8922 | Validation Loss: 0.6424
# Train Loss: 0.7932 | Validation Loss: 0.5476
# Train Loss: 0.7098 | Validation Loss: 0.4869
# Train Loss: 0.6040 | Validation Loss: 0.3546
# Train Loss: 0.4815 | Validation Loss: 0.2799
# Train Loss: 0.4084 | Validation Loss: 0.2142
# Train Loss: 0.3464 | Validation Loss: 0.1611
# Train Loss: 0.3196 | Validation Loss: 0.1430
# Train Loss: 0.3123 | Validation Loss: 0.1482
# Train Loss: 0.3080 | Validation Loss: 0.1490
# Train Loss: 0.3075 | Validation Loss: 0.1595
# Train Loss: 0.3063 | Validation Loss: 0.1445
# Train Loss: 0.3048 | Validation Loss: 0.1556
# Train Loss: 0.3052 | Validation Loss: 0.1358
# Train Loss: 0.3002 | Validation Loss: 0.1435
# Train Loss: 0.2981 | Validation Loss: 0.1516
# Train Loss: 0.2998 | Validation Loss: 0.1352
# Train Loss: 0.2969 | Validation Loss: 0.1356
# Train Loss: 0.2956 | Validation Loss: 0.1382
# Train Loss: 0.2940 | Validation Loss: 0.1291
# ...
# Train Loss: 0.4246 | Validation Loss: 0.2050
# Train Loss: 0.3521 | Validation Loss: 0.1589
# Train Loss: 0.3075 | Validation Loss: 0.1247
# Train Loss: 0.2871 | Validation Loss: 0.1305
# Train Loss: 0.2786 | Validation Loss: 0.1248
# Train Loss: 0.2755 | Validation Loss: 0.1148
# Train Loss: 0.2741 | Validation Loss: 0.1059
# Train Loss: 0.2682 | Validation Loss: 0.1235
# Train Loss: 0.2705 | Validation Loss: 0.1083
# Train Loss: 0.2661 | Validation Loss: 0.1137
# Train Loss: 0.2645 | Validation Loss: 0.1118
# Train Loss: 0.2644 | Validation Loss: 0.1101
# Train Loss: 0.2609 | Validation Loss: 0.1237
# Train Loss: 0.2598 | Validation Loss: 0.1033
# Train Loss: 0.2603 | Validation Loss: 0.1190
# Train Loss: 0.2569 | Validation Loss: 0.1037
# Train Loss: 0.2558 | Validation Loss: 0.1128
# Train Loss: 0.2543 | Validation Loss: 0.0967
# Train Loss: 0.2545 | Validation Loss: 0.1040
# Train Loss: 0.2516 | Validation Loss: 0.1285
# Train Loss: 0.2536 | Validation Loss: 0.1179
# Train Loss: 0.2507 | Validation Loss: 0.1105
# Train Loss: 0.2453 | Validation Loss: 0.1036
# Train Loss: 0.2480 | Validation Loss: 0.1022
# Train Loss: 0.2481 | Validation Loss: 0.1223
# Training complete!
# MAE for ../processed_ds/stores_data/store-949/store-949.csv: 0.3421
#
# Processing Site: ../processed_ds/stores_data/store-842/store-842.csv
# Train size: 476 | Validation size: 118 | Test size: 149
# Train Loss: 1.0196 | Validation Loss: 0.7341
# Train Loss: 1.0133 | Validation Loss: 0.7247
# Train Loss: 0.9962 | Validation Loss: 0.7037
# Train Loss: 0.9627 | Validation Loss: 0.6634
# Train Loss: 0.9121 | Validation Loss: 0.6288
# Train Loss: 0.8607 | Validation Loss: 0.5795
# Train Loss: 0.8044 | Validation Loss: 0.5376
# Train Loss: 0.7452 | Validation Loss: 0.4488
# Train Loss: 0.6712 | Validation Loss: 0.3825
# Train Loss: 0.6031 | Validation Loss: 0.3141
# Train Loss: 0.5387 | Validation Loss: 0.2484
# Train Loss: 0.4818 | Validation Loss: 0.2282
# Train Loss: 0.4146 | Validation Loss: 0.1653
# Train Loss: 0.3805 | Validation Loss: 0.1645
# Train Loss: 0.3819 | Validation Loss: 0.2017
# Train Loss: 0.3806 | Validation Loss: 0.1886
# Train Loss: 0.3689 | Validation Loss: 0.1840
# Train Loss: 0.3645 | Validation Loss: 0.1657
# Train Loss: 0.3675 | Validation Loss: 0.1771
# Train Loss: 0.3566 | Validation Loss: 0.1910
# Train Loss: 0.3595 | Validation Loss: 0.1681
# Train Loss: 0.3511 | Validation Loss: 0.1695
# Train Loss: 0.3491 | Validation Loss: 0.1536
# Train Loss: 0.3493 | Validation Loss: 0.1667
# Train Loss: 0.3483 | Validation Loss: 0.1569
# Train Loss: 0.3340 | Validation Loss: 0.1867
# Train Loss: 0.3424 | Validation Loss: 0.1918
# Train Loss: 0.3410 | Validation Loss: 0.1957
# Train Loss: 0.3361 | Validation Loss: 0.1648
# Train Loss: 0.3284 | Validation Loss: 0.1799
# Training complete!
# MAE for ../processed_ds/stores_data/store-842/store-842.csv: 0.3394
#
# Processing Site: ../processed_ds/stores_data/store-938/store-938.csv
# Train size: 593 | Validation size: 148 | Test size: 186
# Train Loss: 0.9802 | Validation Loss: 0.8098
# Train Loss: 0.9560 | Validation Loss: 0.7703
# Train Loss: 0.8892 | Validation Loss: 0.6607
# Train Loss: 0.7945 | Validation Loss: 0.5865
# Train Loss: 0.7002 | Validation Loss: 0.4494
# Train Loss: 0.5424 | Validation Loss: 0.2850
# Train Loss: 0.4126 | Validation Loss: 0.1808
# Train Loss: 0.3191 | Validation Loss: 0.1212
# Train Loss: 0.2818 | Validation Loss: 0.1144
# Train Loss: 0.2732 | Validation Loss: 0.1092
# Train Loss: 0.2733 | Validation Loss: 0.1118
# Train Loss: 0.2711 | Validation Loss: 0.1106
# Train Loss: 0.2669 | Validation Loss: 0.1130
# Train Loss: 0.2678 | Validation Loss: 0.1019
# Train Loss: 0.2667 | Validation Loss: 0.1082
# Train Loss: 0.2646 | Validation Loss: 0.1024
# Train Loss: 0.2608 | Validation Loss: 0.1023
# Train Loss: 0.2659 | Validation Loss: 0.1010
# Train Loss: 0.2608 | Validation Loss: 0.1053
# Train Loss: 0.2618 | Validation Loss: 0.1044
# Train Loss: 0.2590 | Validation Loss: 0.0976
# Train Loss: 0.2568 | Validation Loss: 0.1010
# Train Loss: 0.2579 | Validation Loss: 0.1006
# Train Loss: 0.2580 | Validation Loss: 0.0965
# Train Loss: 0.2545 | Validation Loss: 0.0994
# Train Loss: 0.2552 | Validation Loss: 0.1011
# Train Loss: 0.2539 | Validation Loss: 0.1026
# Train Loss: 0.2524 | Validation Loss: 0.1030
# Train Loss: 0.2552 | Validation Loss: 0.0990
# Train Loss: 0.2533 | Validation Loss: 0.0973
# Training complete!
# MAE for ../processed_ds/stores_data/store-938/store-938.csv: 0.3059
#
# Processing Site: ../processed_ds/stores_data/store-4/store-4.csv
# Train size: 593 | Validation size: 148 | Test size: 186
# Train Loss: 0.9868 | Validation Loss: 0.7150
# Train Loss: 0.9728 | Validation Loss: 0.6962
# Train Loss: 0.9318 | Validation Loss: 0.6371
# Train Loss: 0.8594 | Validation Loss: 0.5748
# Train Loss: 0.7869 | Validation Loss: 0.5014
# Train Loss: 0.6838 | Validation Loss: 0.4251
# Train Loss: 0.5784 | Validation Loss: 0.3438
# Train Loss: 0.4703 | Validation Loss: 0.2242
# Train Loss: 0.3752 | Validation Loss: 0.1676
# Train Loss: 0.3168 | Validation Loss: 0.1392
# Train Loss: 0.3000 | Validation Loss: 0.1397
# Train Loss: 0.2962 | Validation Loss: 0.1376
# Train Loss: 0.2946 | Validation Loss: 0.1393
# Train Loss: 0.2912 | Validation Loss: 0.1514
# Train Loss: 0.2948 | Validation Loss: 0.1634
# Train Loss: 0.2957 | Validation Loss: 0.1432
# Train Loss: 0.2902 | Validation Loss: 0.1444
# Train Loss: 0.2924 | Validation Loss: 0.1418
# Train Loss: 0.2883 | Validation Loss: 0.1428
# Train Loss: 0.2900 | Validation Loss: 0.1441
# Train Loss: 0.2898 | Validation Loss: 0.1568
# Train Loss: 0.2894 | Validation Loss: 0.1543
# Train Loss: 0.2893 | Validation Loss: 0.1434
# Train Loss: 0.2854 | Validation Loss: 0.1388
# Train Loss: 0.2881 | Validation Loss: 0.1364
# Train Loss: 0.2870 | Validation Loss: 0.1448
# Train Loss: 0.2871 | Validation Loss: 0.1420
# Train Loss: 0.2840 | Validation Loss: 0.1534
# Train Loss: 0.2838 | Validation Loss: 0.1419
# Train Loss: 0.2856 | Validation Loss: 0.1527
# Training complete!
# MAE for ../processed_ds/stores_data/store-4/store-4.csv: 0.3373
#
# Processing Site: ../processed_ds/stores_data/store-1088/store-1088.csv
# Train size: 593 | Validation size: 148 | Test size: 186
# Train Loss: 0.9860 | Validation Loss: 0.7417
# Train Loss: 0.9511 | Validation Loss: 0.6826
# Train Loss: 0.8306 | Validation Loss: 0.5597
# Train Loss: 0.6871 | Validation Loss: 0.4583
# Train Loss: 0.5643 | Validation Loss: 0.3196
# Train Loss: 0.4323 | Validation Loss: 0.2294
# Train Loss: 0.3808 | Validation Loss: 0.2037
# Train Loss: 0.3511 | Validation Loss: 0.1836
# Train Loss: 0.3344 | Validation Loss: 0.1671
# Train Loss: 0.3269 | Validation Loss: 0.1579
# Train Loss: 0.3220 | Validation Loss: 0.1631
# Train Loss: 0.3196 | Validation Loss: 0.1768
# Train Loss: 0.3184 | Validation Loss: 0.1775
# Train Loss: 0.3186 | Validation Loss: 0.1817
# Train Loss: 0.3167 | Validation Loss: 0.1624
# Train Loss: 0.3117 | Validation Loss: 0.1618
# Train Loss: 0.3130 | Validation Loss: 0.1833
# Train Loss: 0.3114 | Validation Loss: 0.1602
# Train Loss: 0.3080 | Validation Loss: 0.1871
# Train Loss: 0.3099 | Validation Loss: 0.1563
# Train Loss: 0.3069 | Validation Loss: 0.1605
# Train Loss: 0.3114 | Validation Loss: 0.1725
# Train Loss: 0.3077 | Validation Loss: 0.1681
# Train Loss: 0.3032 | Validation Loss: 0.1723
# Train Loss: 0.3051 | Validation Loss: 0.1783
# Train Loss: 0.3008 | Validation Loss: 0.2014
# Train Loss: 0.2994 | Validation Loss: 0.1674
# Train Loss: 0.3000 | Validation Loss: 0.1691
# Train Loss: 0.2965 | Validation Loss: 0.1759
# Train Loss: 0.2943 | Validation Loss: 0.1656
# Training complete!
# MAE for ../processed_ds/stores_data/store-1088/store-1088.csv: 0.3764
#
# Processing Site: ../processed_ds/stores_data/store-328/store-328.csv
# Train size: 593 | Validation size: 148 | Test size: 186
# Train Loss: 0.9932 | Validation Loss: 0.7737
# Train Loss: 0.9563 | Validation Loss: 0.7040
# Train Loss: 0.8002 | Validation Loss: 0.5544
# Train Loss: 0.6623 | Validation Loss: 0.4477
# Train Loss: 0.5249 | Validation Loss: 0.3073
# Train Loss: 0.3986 | Validation Loss: 0.2424
# Train Loss: 0.3455 | Validation Loss: 0.2061
# Train Loss: 0.3137 | Validation Loss: 0.1638
# Train Loss: 0.2986 | Validation Loss: 0.1592
# Train Loss: 0.2916 | Validation Loss: 0.1552
# Train Loss: 0.2915 | Validation Loss: 0.1575
# Train Loss: 0.2925 | Validation Loss: 0.1561
# Train Loss: 0.2923 | Validation Loss: 0.1558
# Train Loss: 0.2908 | Validation Loss: 0.1810
# Train Loss: 0.2911 | Validation Loss: 0.1533
# Train Loss: 0.2874 | Validation Loss: 0.1482
# Train Loss: 0.2895 | Validation Loss: 0.1553
# Train Loss: 0.2901 | Validation Loss: 0.1451
# Train Loss: 0.2869 | Validation Loss: 0.1507
# Train Loss: 0.2832 | Validation Loss: 0.1443
# Train Loss: 0.2850 | Validation Loss: 0.1582
# Train Loss: 0.2866 | Validation Loss: 0.1600
# Train Loss: 0.2864 | Validation Loss: 0.1436
# Train Loss: 0.2845 | Validation Loss: 0.1478
# Train Loss: 0.2846 | Validation Loss: 0.1533
# Train Loss: 0.2823 | Validation Loss: 0.1537
# Train Loss: 0.2839 | Validation Loss: 0.1501
# Train Loss: 0.2862 | Validation Loss: 0.1548
# Train Loss: 0.2824 | Validation Loss: 0.1553
# Train Loss: 0.2819 | Validation Loss: 0.1483
# Training complete!
# MAE for ../processed_ds/stores_data/store-328/store-328.csv: 0.3338
#
# Processing Site: ../processed_ds/stores_data/store-70/store-70.csv
# Train size: 593 | Validation size: 148 | Test size: 186
# Train Loss: 0.9735 | Validation Loss: 0.6947
# Train Loss: 0.9575 | Validation Loss: 0.6682
# Train Loss: 0.9200 | Validation Loss: 0.5955
# Train Loss: 0.8383 | Validation Loss: 0.5095
# Train Loss: 0.7726 | Validation Loss: 0.4579
# Train Loss: 0.7062 | Validation Loss: 0.3716
# Train Loss: 0.5894 | Validation Loss: 0.2664
# Train Loss: 0.4795 | Validation Loss: 0.1927
# Train Loss: 0.3973 | Validation Loss: 0.1241
# Train Loss: 0.3389 | Validation Loss: 0.1088
# Train Loss: 0.3208 | Validation Loss: 0.1020
# Train Loss: 0.3136 | Validation Loss: 0.1146
# Train Loss: 0.3097 | Validation Loss: 0.1107
# Train Loss: 0.3121 | Validation Loss: 0.1042
# Train Loss: 0.3109 | Validation Loss: 0.1127
# Train Loss: 0.3085 | Validation Loss: 0.1149
# Train Loss: 0.3065 | Validation Loss: 0.1014
# Train Loss: 0.3103 | Validation Loss: 0.1010
# Train Loss: 0.3037 | Validation Loss: 0.0949
# Train Loss: 0.3038 | Validation Loss: 0.0915
# Train Loss: 0.3037 | Validation Loss: 0.1068
# Train Loss: 0.2999 | Validation Loss: 0.1056
# Train Loss: 0.2977 | Validation Loss: 0.1024
# Train Loss: 0.2975 | Validation Loss: 0.1026
# Train Loss: 0.2991 | Validation Loss: 0.0976
# Train Loss: 0.2966 | Validation Loss: 0.1030
# Train Loss: 0.2917 | Validation Loss: 0.0961
# Train Loss: 0.2892 | Validation Loss: 0.0916
# Train Loss: 0.2866 | Validation Loss: 0.1155
# Train Loss: 0.2839 | Validation Loss: 0.0980
# Training complete!
# MAE for ../processed_ds/stores_data/store-70/store-70.csv: 0.3318
#
# Processing Site: ../processed_ds/stores_data/store-425/store-425.csv
# Train size: 593 | Validation size: 148 | Test size: 186
# Train Loss: 0.9822 | Validation Loss: 0.7414
# Train Loss: 0.9429 | Validation Loss: 0.6760
# Train Loss: 0.8062 | Validation Loss: 0.5628
# Train Loss: 0.6930 | Validation Loss: 0.4813
# Train Loss: 0.5784 | Validation Loss: 0.3455
# Train Loss: 0.4496 | Validation Loss: 0.2765
# Train Loss: 0.3939 | Validation Loss: 0.2335
# Train Loss: 0.3580 | Validation Loss: 0.2303
# Train Loss: 0.3461 | Validation Loss: 0.1996
# Train Loss: 0.3354 | Validation Loss: 0.2019
# Train Loss: 0.3350 | Validation Loss: 0.1992
# Train Loss: 0.3325 | Validation Loss: 0.1977
# Train Loss: 0.3320 | Validation Loss: 0.1987
# Train Loss: 0.3289 | Validation Loss: 0.2022
# Train Loss: 0.3275 | Validation Loss: 0.2044
# Train Loss: 0.3285 | Validation Loss: 0.2079
# Train Loss: 0.3287 | Validation Loss: 0.2015
# Train Loss: 0.3294 | Validation Loss: 0.2063
# Train Loss: 0.3269 | Validation Loss: 0.2052
# Train Loss: 0.3256 | Validation Loss: 0.2065
# Train Loss: 0.3251 | Validation Loss: 0.1982
# Train Loss: 0.3228 | Validation Loss: 0.2154
# Train Loss: 0.3232 | Validation Loss: 0.2017
# Train Loss: 0.3234 | Validation Loss: 0.2097
# Train Loss: 0.3197 | Validation Loss: 0.2095
# Train Loss: 0.3230 | Validation Loss: 0.2004
# Train Loss: 0.3215 | Validation Loss: 0.2203
# Train Loss: 0.3149 | Validation Loss: 0.2063
# Train Loss: 0.3143 | Validation Loss: 0.2196
# Train Loss: 0.3168 | Validation Loss: 0.2082
# Training complete!
# MAE for ../processed_ds/stores_data/store-425/store-425.csv: 0.3772
#
# Processing Site: ../processed_ds/stores_data/store-768/store-768.csv
# Train size: 593 | Validation size: 148 | Test size: 186
# Train Loss: 0.9782 | Validation Loss: 0.7705
# Train Loss: 0.9556 | Validation Loss: 0.7368
# Train Loss: 0.9038 | Validation Loss: 0.6566
# Train Loss: 0.8072 | Validation Loss: 0.5732
# Train Loss: 0.7206 | Validation Loss: 0.4935
# Train Loss: 0.6319 | Validation Loss: 0.3727
# Train Loss: 0.5169 | Validation Loss: 0.2823
# Train Loss: 0.4300 | Validation Loss: 0.2125
# Train Loss: 0.3477 | Validation Loss: 0.1583
# Train Loss: 0.3103 | Validation Loss: 0.1488
# Train Loss: 0.2940 | Validation Loss: 0.1639
# Train Loss: 0.2852 | Validation Loss: 0.1440
# Train Loss: 0.2794 | Validation Loss: 0.1686
# Train Loss: 0.2747 | Validation Loss: 0.1717
# Train Loss: 0.2664 | Validation Loss: 0.1644
# Train Loss: 0.2624 | Validation Loss: 0.1781
# Train Loss: 0.2580 | Validation Loss: 0.1938
# Train Loss: 0.2506 | Validation Loss: 0.2102
# Train Loss: 0.2491 | Validation Loss: 0.2377
# Train Loss: 0.2415 | Validation Loss: 0.2253
# Train Loss: 0.2322 | Validation Loss: 0.2323
# Train Loss: 0.2390 | Validation Loss: 0.2315
# Train Loss: 0.2348 | Validation Loss: 0.2518
# Train Loss: 0.2265 | Validation Loss: 0.3041
# Train Loss: 0.2291 | Validation Loss: 0.2276
# Train Loss: 0.2323 | Validation Loss: 0.2169
# Train Loss: 0.2145 | Validation Loss: 0.2863
# Train Loss: 0.2105 | Validation Loss: 0.4135
# Train Loss: 0.2133 | Validation Loss: 0.3010
# Train Loss: 0.2050 | Validation Loss: 0.3249
# Training complete!
# MAE for ../processed_ds/stores_data/store-768/store-768.csv: 0.3798
#
# Processing Site: ../processed_ds/stores_data/store-711/store-711.csv
# Train size: 476 | Validation size: 118 | Test size: 149
# Train Loss: 1.0453 | Validation Loss: 0.7590
# Train Loss: 1.0334 | Validation Loss: 0.7398
# Train Loss: 1.0112 | Validation Loss: 0.6931
# Train Loss: 0.9601 | Validation Loss: 0.5923
# Train Loss: 0.8757 | Validation Loss: 0.4600
# Train Loss: 0.8016 | Validation Loss: 0.4206
# Train Loss: 0.7721 | Validation Loss: 0.3666
# Train Loss: 0.7018 | Validation Loss: 0.3009
# Train Loss: 0.6222 | Validation Loss: 0.2089
# Train Loss: 0.5667 | Validation Loss: 0.1772
# Train Loss: 0.5280 | Validation Loss: 0.1523
# Train Loss: 0.4746 | Validation Loss: 0.1393
# Train Loss: 0.4532 | Validation Loss: 0.0852
# Train Loss: 0.4265 | Validation Loss: 0.1514
# Train Loss: 0.4204 | Validation Loss: 0.1435
# Train Loss: 0.4074 | Validation Loss: 0.1203
# Train Loss: 0.4074 | Validation Loss: 0.2147
# Train Loss: 0.4014 | Validation Loss: 0.1396
# Train Loss: 0.3939 | Validation Loss: 0.2185
# Train Loss: 0.4022 | Validation Loss: 0.1480
# Train Loss: 0.3966 | Validation Loss: 0.1624
# Train Loss: 0.3768 | Validation Loss: 0.1355
# Train Loss: 0.3843 | Validation Loss: 0.3111
# Train Loss: 0.3740 | Validation Loss: 0.1204
# Train Loss: 0.3694 | Validation Loss: 0.1925
# Train Loss: 0.3701 | Validation Loss: 0.2412
# Train Loss: 0.3615 | Validation Loss: 0.3746
# Train Loss: 0.3649 | Validation Loss: 0.2763
# Train Loss: 0.3548 | Validation Loss: 0.3352
# Train Loss: 0.3568 | Validation Loss: 0.2998
# Training complete!
# MAE for ../processed_ds/stores_data/store-711/store-711.csv: 0.3132
#
# Processing Site: ../processed_ds/stores_data/store-379/store-379.csv
# Train size: 593 | Validation size: 148 | Test size: 186
# Train Loss: 0.9827 | Validation Loss: 0.8483
# Train Loss: 0.9621 | Validation Loss: 0.8075
# Train Loss: 0.8956 | Validation Loss: 0.6858
# Train Loss: 0.7795 | Validation Loss: 0.5879
# Train Loss: 0.6909 | Validation Loss: 0.4702
# Train Loss: 0.5531 | Validation Loss: 0.3231
# Train Loss: 0.4461 | Validation Loss: 0.2451
# Train Loss: 0.3638 | Validation Loss: 0.1871
# Train Loss: 0.3167 | Validation Loss: 0.1537
# Train Loss: 0.2999 | Validation Loss: 0.1497
# Train Loss: 0.3026 | Validation Loss: 0.1482
# Train Loss: 0.2977 | Validation Loss: 0.1560
# Train Loss: 0.2957 | Validation Loss: 0.1470
